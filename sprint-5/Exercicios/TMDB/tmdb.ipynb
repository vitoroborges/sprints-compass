# %% [markdown]
# ## Módulos usados

# %%
import requests
import pandas as pd
from IPython.display import display
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Código

# %%
load_dotenv()

api_key = os.getenv("API_KEY")

url = f'https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=pt-BR'

response = requests.get(url)
data = response.json()

filmes = []

for movie in data['results']:
    df = {
        'Titulo': movie['title'],
        'Data lançamento': movie['release_date'],
        'Visão geral': movie['overview'],
        'Votos': movie['vote_count'],
        'Media de votos': movie['vote_average'],
    }
    filmes.append(df)

df = pd.DataFrame(filmes)
display(df)
# Out:
#                                    Titulo Data lançamento  \
# 0                   Um Sonho de Liberdade      1994-09-23
# 1                       O Poderoso Chefão      1972-03-14
# 2             O Poderoso Chefão: Parte II      1974-12-20
# 3                    A Lista de Schindler      1993-12-15
# 4                12 Homens e uma Sentença      1957-04-10
# 5                     A Viagem de Chihiro      2001-07-20
# 6          Batman: O Cavaleiro das Trevas      2008-07-16
# 7               Dilwale vai levar a noiva      1995-10-20
# 8                  À Espera de um Milagre      1999-12-10
# 9                                Parasita      2019-05-30
# 10       Pulp Fiction: Tempo de Violência      1994-09-10
# 11                              Your Name      2016-08-26
# 12   O Senhor dos Anéis: O Retorno do Rei      2003-12-17
# 13  Forrest Gump: O Contador de Histórias      1994-06-23
# 14                Três Homens em Conflito      1966-12-22
# 15                       Os Sete Samurais      1954-04-26
# 16                   Os Bons Companheiros      1990-09-12
# 17                           Interestelar      2014-11-05
# 18                 O Túmulo dos Vagalumes      1988-04-16
# 19                          A Vida é Bela      1997-12-20
#
#                                           Visão geral  Votos  Media de votos
# 0   Em 1946, Andy Dufresne, um banqueiro jovem e b...  28197           8.709
# 1   Em 1945, Don Corleone é o chefe de uma mafiosa...  21375           8.687
# 2   Após a máfia matar sua família, o jovem Vito f...  12916           8.571
# 3   O alemão Oskar Schindler viu na mão de obra ju...  16389           8.564
# 4   Um jovem porto-riquenho é acusado do brutal cr...   9093           8.548
# 5   Chihiro e seus pais estão se mudando para uma ...  17078           8.536
# 6   Após dois anos desde o surgimento do Batman, o...  33766           8.500
# 7   Raj e Simran são dois jovens indianos vivendo ...   4484           8.516
# 8   Milagres acontecem em lugares inesperados, mes...  18036           8.504
# 9   Toda a família de Ki-taek está desempregada, v...  18984           8.500
# 10  Vincent Vega e Jules Winnfield são dois assass...  28606           8.489
# 11  Mitsuha é a filha do prefeito de uma pequena c...  11731           8.485
# 12  O confronto final entre as forças do bem e do ...  25008           8.483
# 13  Quarenta anos da história dos Estados Unidos, ...  28142           8.468
# 14  Durante o auge da Guerra Civil, um misterioso ...   8952           8.500
# 15  Um bando de bandidos aterroriza os habitantes ...   3876           8.458
# 16  A história real de Henry Hill, um garoto meio ...  13318           8.455
# 17  As reservas naturais da Terra estão chegando a...  37026           8.454
# 18  O filme relata a história de dois irmãos, Seit...   5856           8.451
# 19  Durante a Segunda Guerra Mundial na Itália, o ...  13325           8.449
